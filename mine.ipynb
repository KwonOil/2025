# %% [markdown]
# # Pico.css : "클래스 없는" 스타일링
# - Pico.css의 핵심 철학은 **"HTML 태그 본연의 모습에 스타일을 입히자"**는 것.
# - 복잡하게 class="btn-primary" 같은 클래스 이름을 붙이지 않아도, ``<button>`` 태그는 버튼답게, ``<input>``은 입력창답게 자동으로 디자인된다.

# %%
<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@picocss/pico@1/css/pico.min.css">
