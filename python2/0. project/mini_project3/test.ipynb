# %%
import pandas as pd
import sqlalchemy

engine = sqlalchemy.create_engine("mysql+pymysql://root:1234@192.168.0.115/miniproject")

data = pd.read_csv('data\seoul_weather_2025_09.csv', encoding='euc-kr')
data.info()

data.to_sql(name='seoul_weather_2025_09', con=engine, if_exists='replace', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24539 entries, 0 to 24538
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지점          24539 non-null  int64
#  1   일시          24539 non-null  object
#  2   기온(°C)      24539 non-null  float64
#  3   누적강수량(mm)   24539 non-null  float64
#  4   풍향(deg)     24077 non-null  float64
#  5   풍속(m/s)     24077 non-null  float64
#  6   현지기압(hPa)   24539 non-null  float64
#  7   해면기압(hPa)   24539 non-null  float64
#  8   습도(%)       24539 non-null  float64
#  9   일사(MJ/m^2)  24076 non-null  float64
#  10  일조(Sec)     24077 non-null  float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 2.1+ MB
# 24539
